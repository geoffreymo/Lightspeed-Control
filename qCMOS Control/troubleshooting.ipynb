# %%
import numpy as np
from astropy.io import fits
from labjack import ljm

# %%
ljm_handle = ljm.openS("T4", "USB", "ANY")
print(ljm.eReadName(ljm_handle, "FIO4"))
ljm.eWriteName(ljm_handle, "DIO4", 1.0)
print(ljm.eReadName(ljm_handle, "DIO4"))
ljm.close(ljm_handle)
# Out:
# 1.0
# 1.0
